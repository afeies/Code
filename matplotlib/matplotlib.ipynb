# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create data

# %%
X_data = np.random.random(1000) * 100
y_data = np.random.random(1000) * 100

# %% [markdown]
# ### Scatter plot: plt.scatter(X, y)

# %%
# scatter on x, y
# can call color names, hex, rgb
plt.scatter(X_data, y_data, c="red", marker="*", s=150, alpha=0.3)

# %% [markdown]
# ### Line plots: plt.plot(X, y)

# %%
years = [2006 + x for x in range(16)]
weights = [80, 83, 84, 85, 86, 82, 81, 79, 83, 80, 82, 82, 83, 81, 80, 79]

# "r--"
plt.plot(years, weights, c="red", lw="5", linestyle="--")

# %% [markdown]
# ### Bar plots: plt.bar(x, y)

# %%
X = ["C++", "C#", "Python", "Java", "Go"]
y = [20, 50, 140, 1, 45]

plt.bar(X, y, color="r", align="edge", width=0.4, edgecolor="black")
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Histograms: plt.hist(x)
# - np.random.normal(mean, std, size)

# %%
ages = np.random.normal(20, 1.5, 1000)
# bins = 20
plt.hist(ages, bins=[ages.min(), 18, 19, 20, 21, 22, ages.max()], cumulative=True)
# Out:
# (array([  92.,  236.,  496.,  750.,  907., 1000.]),
#  array([15.01757249, 18.        , 19.        , 20.        , 21.        ,
#         22.        , 24.53162753]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# ### Pie charts: plt.pie(freq, labels=...)

# %%
langs = ["Python", "C++", "Java", "C#", "Go"]
votes = [50, 24, 14, 6, 17]
explodes = [0.3, 0, 0, 0, 0]
plt.pie(votes, labels=langs, explode=explodes, autopct="%.2f%%", pctdistance=1.4, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x117d92990>,
#   <matplotlib.patches.Wedge at 0x117d92d50>,
#   <matplotlib.patches.Wedge at 0x117d93110>,
#   <matplotlib.patches.Wedge at 0x117d934d0>,
#   <matplotlib.patches.Wedge at 0x117d93890>],
#  [Text(-1.3830721972891218, 0.21705136969353725, 'Python'),
#   Text(0.39565756583368106, -1.0263796035573616, 'C++'),
#   Text(1.0910905157734931, -0.13971931287095868, 'Java'),
#   Text(0.9958393630027954, 0.4672300965201053, 'C#'),
#   Text(0.5090735080769894, 0.9751123849968205, 'Go')],
#  [Text(-1.6794448109939335, 0.2635623774850095, '45.05%'),
#   Text(0.5035641746974122, -1.30630131361846, '21.62%'),
#   Text(1.3886606564389912, -0.17782458001758372, '12.61%'),
#   Text(1.2674319165490122, 0.5946564864801339, '5.41%'),
#   Text(0.6479117375525318, 1.2410521263595897, '15.32%')])

# %% [markdown]
# ### Boxplots: plt.boxplot(x)

# %%
heights = np.random.normal(172, 8, 300)
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x117df7390>,
#   <matplotlib.lines.Line2D at 0x117df74d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x117df7610>,
#   <matplotlib.lines.Line2D at 0x117df7750>],
#  'boxes': [<matplotlib.lines.Line2D at 0x117df7250>],
#  'medians': [<matplotlib.lines.Line2D at 0x117df7890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x117df79d0>],
#  'means': []}

# %% [markdown]
# ### np.linspace
# - linearly space numbers

# %%
first = np.linspace(0, 10, 25)
second = np.linspace(10, 200, 25)
third = np.linspace(200, 210, 25)
fourth = np.linspace(210, 230, 25)

data = np.concatenate((first, second, third, fourth))
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12000a490>,
#   <matplotlib.lines.Line2D at 0x12000a5d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x12000a710>,
#   <matplotlib.lines.Line2D at 0x12000a850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12000a350>],
#  'medians': [<matplotlib.lines.Line2D at 0x12000a990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12000aad0>],
#  'means': []}
